# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dataset = pd.read_csv(r'C:\Users\Dell\Desktop\Data Analyst\MNC_hr_dataset.csv')

# %%
dataset
# Out:
#          Unnamed: 0 Employee_ID         Full_Name  Department  \
# 0                 0  EMP0000001     Joshua Nguyen          IT
# 1                 1  EMP0000002    Julie Williams   Marketing
# 2                 2  EMP0000003   Alyssa Martinez          HR
# 3                 3  EMP0000004   Nicholas Valdez          IT
# 4                 4  EMP0000005    Joel Hendricks  Operations
# ...             ...         ...               ...         ...
# 1999995     1999995  EMP1999996      Cody Russell  Operations
# 1999996     1999996  EMP1999997      Tracey Smith          IT
# 1999997     1999997  EMP1999998         Tracy Lee       Sales
# 1999998     1999998  EMP1999999  Michael Roberson          IT
# 1999999     1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title   Hire_Date  \
# 0                    Software Engineer  2011-08-10
# 1                       SEO Specialist  2018-03-02
# 2                           HR Manager  2023-03-20
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# Employee_ID           0
# Full_Name             0
# Department            0
# Job_Title             0
# Hire_Date             0
# Location              0
# Performance_Rating    0
# Experience_Years      0
# Status                0
# Work_Mode             0
# Salary_INR            0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   Employee_ID         object
#  2   Full_Name           object
#  3   Department          object
#  4   Job_Title           object
#  5   Hire_Date           object
#  6   Location            object
#  7   Performance_Rating  int64
#  8   Experience_Years    int64
#  9   Status              object
#  10  Work_Mode           object
#  11  Salary_INR          int64
# dtypes: int64(4), object(8)
# memory usage: 183.1+ MB

# %%
dataset.drop('Unnamed: 0' , axis=1, inplace = True)

# %%
dataset.head(5)
# Out:
#   Employee_ID        Full_Name  Department              Job_Title   Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer  2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist  2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager  2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer  2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator  2024-12-09
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
# 4     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR
# 0                14  Resigned   On-site     1585363
# ...

# %%
dataset['Hire_Date'] = pd.to_datetime(dataset['Hire_Date'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Employee_ID         object
#  1   Full_Name           object
#  2   Department          object
#  3   Job_Title           object
#  4   Hire_Date           datetime64[ns]
#  5   Location            object
#  6   Performance_Rating  int64
#  7   Experience_Years    int64
#  8   Status              object
#  9   Work_Mode           object
#  10  Salary_INR          int64
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 167.8+ MB

# %%
dataset.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
dataset['Experience_Years'].nunique()
# Out:
# 16

# %%
dataset['Experience_Years'].unique()
# Out:
# array([14,  7,  2,  1,  0,  4,  9,  5,  6,  8,  3, 10, 11, 12, 13, 15])

# %%
sns.countplot( x = 'Experience_Years', data = dataset);

# %%
dataset.select_dtypes( include = 'object')
# Out:
#         Employee_ID         Full_Name  Department  \
# 0        EMP0000001     Joshua Nguyen          IT
# 1        EMP0000002    Julie Williams   Marketing
# 2        EMP0000003   Alyssa Martinez          HR
# 3        EMP0000004   Nicholas Valdez          IT
# 4        EMP0000005    Joel Hendricks  Operations
# ...             ...               ...         ...
# 1999995  EMP1999996      Cody Russell  Operations
# 1999996  EMP1999997      Tracey Smith          IT
# 1999997  EMP1999998         Tracy Lee       Sales
# 1999998  EMP1999999  Michael Roberson          IT
# 1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title  \
# 0                    Software Engineer
# 1                       SEO Specialist
# 2                           HR Manager
# 3                    Software Engineer
# 4                Logistics Coordinator
# ...                                ...
# 1999995          Logistics Coordinator
# ...

# %%
dataset.select_dtypes( include = 'int')
# Out:
#          Performance_Rating  Experience_Years  Salary_INR
# 0                         5                14     1585363
# 1                         2                 7      847686
# 2                         1                 2     1430084
# 3                         1                 1      990689
# 4                         5                 0      535082
# ...                     ...               ...         ...
# 1999995                   3                14      657648
# 1999996                   3                 4     1030109
# 1999997                   5                 1     1313085
# 1999998                   4                 2     1479727
# 1999999                   1                 4      993718
#
# [2000000 rows x 3 columns]

# %% [markdown]
# Solving Queries

# %%
dataset.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
dataset.Status.unique()
# Out:
# array(['Resigned', 'Active', 'Terminated', 'Retired'], dtype=object)

# %%
for_pie = dataset.Status.value_counts()

# %%
for_pie
# Out:
# Status
# Active        1401558
# Resigned       398660
# Retired         99912
# Terminated      99870
# Name: count, dtype: int64

# %%
for_pie.plot(kind = 'pie', colors = 'gcyr', autopct = '%1.1f%%', explode =(0.01, 0.02, 0.03, 0.04), shadow = True);

# %%
dataset.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
dataset['Work_Mode'].unique()
# Out:
# array(['On-site', 'Remote'], dtype=object)

# %%
for_pie2 = dataset['Work_Mode'].value_counts()

# %%
for_pie2
# Out:
# Work_Mode
# On-site    1199109
# Remote      800891
# Name: count, dtype: int64

# %%
for_pie2.plot(kind = 'pie' , autopct = '%1.1f%%', shadow = True);

# %%
dataset.head()
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
# 4     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR
# 0                14  Resigned   On-site     1585363
# ...

# %%
dataset.Department.unique()
# Out:
# array(['IT', 'Marketing', 'HR', 'Operations', 'Finance', 'Sales', 'R&D'],
#       dtype=object)

# %%
dataset.Department.value_counts()

# %%
plt.figure(figsize = (9,5))
plt.bar(dataset.Department.value_counts().index, dataset.Department.value_counts().values);

# %%
sns.countplot(x = "Department", data = dataset);

# %%
dataset['Job_Title'].value_counts()
# Out:
# Job_Title
# Software Engineer                300358
# Sales Executive                  199982
# Operations Executive             150058
# Data Analyst                     120375
# Marketing Executive              120154
# Account Manager                  119929
# Accountant                       100307
# DevOps Engineer                   90197
# Logistics Coordinator             90188
# HR Executive                      79348
# SEO Specialist                    71692
# Business Development Manager      60233
# IT Manager                        60224
# Financial Analyst                 59815
# Research Scientist                50017
# Talent Acquisition Specialist     47994
# Supply Chain Manager              44935
# Content Strategist                36154
# CTO                               29888
# Product Developer                 29872
# Finance Manager                   29799
# HR Manager                        23841
# Sales Director                    19887
# ...

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'Job_Title' , data = dataset);
plt.xticks( rotation = 'vertical');

# %%
dataset.groupby('Department')['Job_Title'].value_counts()
# Out:
# Department  Job_Title
# Finance     Accountant                       100307
#             Financial Analyst                 59815
#             Finance Manager                   29799
#             CFO                                9952
# HR          HR Executive                      79348
#             Talent Acquisition Specialist     47994
#             HR Manager                        23841
#             HR Director                        7936
# IT          Software Engineer                300358
#             Data Analyst                     120375
#             DevOps Engineer                   90197
#             IT Manager                        60224
#             CTO                               29888
# Marketing   Marketing Executive              120154
#             SEO Specialist                    71692
#             Content Strategist                36154
#             Brand Manager                     12081
# Operations  Operations Executive             150058
# ...

# %%
dataset.head(5)
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
# 4     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR
# 0                14  Resigned   On-site     1585363
# ...

# %%
earnings = dataset.groupby('Department')['Salary_INR'].mean()/1000

# %%
earnings
# Out:
# Department
# Finance        940.411743
# HR             743.853561
# IT            1129.858151
# Marketing      769.936152
# Operations     754.626253
# R&D            800.377157
# Sales          792.957860
# Name: Salary_INR, dtype: float64

# %%
earnings.plot(x = earnings.index, y =  earnings.values, kind = 'barh', legend = True);
plt.grid();

# %%
dataset.head(3)
# Out:
#   Employee_ID        Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams  Marketing     SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez         HR         HR Manager 2023-03-20
#
#                            Location  Performance_Rating  Experience_Years  \
# 0                Isaacland, Denmark                   5                14
# 1           Anthonyside, Costa Rica                   2                 7
# 2  Port Christinaport, Saudi Arabia                   1                 2
#
#      Status Work_Mode  Salary_INR
# 0  Resigned   On-site     1585363
# 1    Active   On-site      847686
# 2    Active   On-site     1430084

# %%
jt_salary = dataset.groupby('Job_Title')['Salary_INR'].mean()/1000

# %%
jt_salary.sort_values(ascending = False)
# Out:
# Job_Title
# IT Manager                       2098.155777
# Finance Manager                  1743.241525
# HR Manager                       1252.401915
# Business Development Manager     1252.016231
# Software Engineer                1199.260843
# Financial Analyst                1051.522903
# Brand Manager                     803.127787
# Innovation Manager                801.870103
# Talent Acquisition Specialist     801.422237
# CTO                               801.402754
# Research Scientist                801.314879
# Data Analyst                      800.996380
# Content Strategist                800.760030
# HR Director                       800.694437
# Operations Executive              800.350915
# Lab Technician                    800.181468
# DevOps Engineer                   799.949184
# Account Manager                   799.373734
# Sales Director                    799.069374
# Marketing Executive               798.780404
# Product Developer                 798.652261
# ...

# %%
plt.figure(figsize = (9,5))
jt_salary.plot(x = jt_salary.index, y = jt_salary.values, kind = 'bar', color = 'cyan', legend = True);
plt.xticks(rotation = 'vertical');
plt.title('Average Salary wrt Job Title')
plt.ylabel('Salary');

# %%
dataset.head(3)
# Out:
#   Employee_ID        Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams  Marketing     SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez         HR         HR Manager 2023-03-20
#
#                            Location  Performance_Rating  Experience_Years  \
# 0                Isaacland, Denmark                   5                14
# 1           Anthonyside, Costa Rica                   2                 7
# 2  Port Christinaport, Saudi Arabia                   1                 2
#
#      Status Work_Mode  Salary_INR
# 0  Resigned   On-site     1585363
# 1    Active   On-site      847686
# 2    Active   On-site     1430084

# %%
dj  = dataset.groupby(['Department', 'Job_Title'])['Salary_INR'].mean()/1000

# %%
dj
# Out:
# Department  Job_Title
# Finance     Accountant                        650.076482
#             CFO                               795.015873
#             Finance Manager                  1743.241525
#             Financial Analyst                1051.522903
# HR          HR Director                       800.694437
#             HR Executive                      550.548859
#             HR Manager                       1252.401915
#             Talent Acquisition Specialist     801.422237
# IT          CTO                               801.402754
#             Data Analyst                      800.996380
#             DevOps Engineer                   799.949184
#             IT Manager                       2098.155777
#             Software Engineer                1199.260843
# Marketing   Brand Manager                     803.127787
#             Content Strategist                800.760030
#             Marketing Executive               798.780404
# ...

# %%
dj.plot();
plt.xticks(rotation = 'vertical');
plt.title('Average Salary in Different Department')
plt.ylabel('Salary');

# %%
plt.figure(figsize = (9,7))
dj.plot(kind = 'barh');
plt.title('Average Salary in Different Department')
plt.xlabel('Salary');
plt.savefig('Department_Job-Title_salary.png', bbox_inches = 'tight');

# %%
dataset.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
dataset.Status.unique()
# Out:
# array(['Resigned', 'Active', 'Terminated', 'Retired'], dtype=object)

# %%
for_resigned = dataset[dataset.Status == 'Resigned']

# %%
for_resigned
# Out:
#         Employee_ID         Full_Name  Department              Job_Title  \
# 0        EMP0000001     Joshua Nguyen          IT      Software Engineer
# 8        EMP0000009    Cathy Thompson     Finance      Financial Analyst
# 11       EMP0000012        Kevin Lowe       Sales        Account Manager
# 16       EMP0000017     Robert Martin  Operations  Logistics Coordinator
# 19       EMP0000020    Donald Hoffman   Marketing     Content Strategist
# ...             ...               ...         ...                    ...
# 1999976  EMP1999977     Angela Curtis  Operations   Operations Executive
# 1999983  EMP1999984      Joshua Ponce       Sales        Account Manager
# 1999985  EMP1999986  Aaron Montgomery   Marketing    Marketing Executive
# 1999986  EMP1999987      Mason Parker  Operations   Operations Executive
# 1999989  EMP1999990      Adrian Lopez       Sales        Sales Executive
#
#          Hire_Date                      Location  Performance_Rating  \
# ...

# %%
resigned_graph = for_resigned.groupby('Department')['Status'].count()

# %%
resigned_graph
# Out:
# Department
# Finance        40238
# HR             31736
# IT            119852
# Marketing      47793
# Operations     59397
# R&D            19919
# Sales          79725
# Name: Status, dtype: int64

# %%
resigned_graph.plot(kind = 'barh');
plt.grid()
plt.title('Resigned Employees')
plt.xlabel('Values');
plt.savefig('Resigned_Employees_Bgraph.png' , bbox_inches = 'tight');

# %%
for_terminated = dataset[dataset.Status == 'Terminated']

# %%
for_terminated
# Out:
#         Employee_ID              Full_Name Department            Job_Title  \
# 20       EMP0000021  Mr. Billy Rodgers DDS  Marketing  Marketing Executive
# 33       EMP0000034          Steve Carlson         IT    Software Engineer
# 56       EMP0000057        Claire Martinez         IT      DevOps Engineer
# 100      EMP0000101         Johnny Shepard    Finance           Accountant
# 121      EMP0000122          Vanessa Brown         IT         Data Analyst
# ...             ...                    ...        ...                  ...
# 1999912  EMP1999913     Stefanie Valentine  Marketing   Content Strategist
# 1999936  EMP1999937            Lisa Gordon    Finance    Financial Analyst
# 1999947  EMP1999948           John Johnson      Sales      Sales Executive
# 1999981  EMP1999982         Mindy Campbell      Sales      Account Manager
# 1999993  EMP1999994          Ashley Fuller         IT      DevOps Engineer
#
# ...

# %%
terminated_graph = for_terminated.groupby('Department')['Status'].count()

# %%
terminated_graph
# Out:
# Department
# Finance        9988
# HR             7861
# IT            29881
# Marketing     12044
# Operations    14884
# R&D            4998
# Sales         20214
# Name: Status, dtype: int64

# %%
terminated_graph.plot(kind = 'barh');
plt.grid()
plt.title('Terminated Exployees')
plt.xlabel('Values');
plt.savefig('Terminated_Employees-Graph.png' , bbox_inches = 'tight');

# %%
dataset.head(3)
# Out:
#   Employee_ID        Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams  Marketing     SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez         HR         HR Manager 2023-03-20
#
#                            Location  Performance_Rating  Experience_Years  \
# 0                Isaacland, Denmark                   5                14
# 1           Anthonyside, Costa Rica                   2                 7
# 2  Port Christinaport, Saudi Arabia                   1                 2
#
#      Status Work_Mode  Salary_INR
# 0  Resigned   On-site     1585363
# 1    Active   On-site      847686
# 2    Active   On-site     1430084

# %%
dataset['Experience_Years'].unique()
# Out:
# array([14,  7,  2,  1,  0,  4,  9,  5,  6,  8,  3, 10, 11, 12, 13, 15])

# %%
ex_sa = dataset.groupby('Experience_Years')['Salary_INR'].mean()

# %%
ex_sa
# Out:
# Experience_Years
# 0     896737.454775
# 1     895903.759824
# 2     896755.652313
# 3     896861.245240
# 4     897944.573965
# 5     896484.084828
# 6     896012.632467
# 7     895722.673960
# 8     897148.361090
# 9     898482.940577
# 10    895662.027882
# 11    901452.750112
# 12    896432.933416
# 13    898790.197041
# 14    895610.790251
# 15    895647.401051
# Name: Salary_INR, dtype: float64

# %%
ex_sa.plot(legend = True);
plt.title('Salary varies with Experience')
plt.ylabel('Salary');

# %%
dataset.head(4)
# Out:
#   Employee_ID        Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams  Marketing     SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez         HR         HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez         IT  Software Engineer 2023-10-12
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
#
#    Experience_Years    Status Work_Mode  Salary_INR
# 0                14  Resigned   On-site     1585363
# 1                 7    Active   On-site      847686
# 2                 2    Active   On-site     1430084
# 3                 1    Active   On-site      990689

# %%
dataset.Department.unique()
# Out:
# array(['IT', 'Marketing', 'HR', 'Operations', 'Finance', 'Sales', 'R&D'],
#       dtype=object)

# %%
dataset.groupby('Department')['Performance_Rating'].mean()
# Out:
# Department
# Finance       2.996818
# HR            2.995670
# IT            2.998216
# Marketing     3.004736
# Operations    2.996081
# R&D           3.001885
# Sales         3.006362
# Name: Performance_Rating, dtype: float64

# %%
dataset.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR
# 0   On-site     1585363
# 1   On-site      847686

# %%
dataset['Country'] = dataset['Location'].apply(lambda x : str(x.split(',')[1]))

# %%
dataset.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR      Country
# 0   On-site     1585363      Denmark
# 1   On-site      847686   Costa Rica

# %%
dataset.Country.value_counts()
# Out:
# Country
# Congo                     16286
# Korea                     16285
# Sri Lanka                  8409
# Switzerland                8391
# British Virgin Islands     8373
#                           ...
# Guinea-Bissau              7983
# Kazakhstan                 7973
# Montenegro                 7972
# Bhutan                     7971
# Palestinian Territory      7895
# Name: count, Length: 243, dtype: int64

# %%
dataset['Performance_Rating'].corr(dataset['Salary_INR'])
# Out:
# np.float64(-0.00020919799940916507)

# %%
#or
dataset[['Performance_Rating', 'Salary_INR']].corr()
# Out:
#                     Performance_Rating  Salary_INR
# Performance_Rating            1.000000   -0.000209
# Salary_INR                   -0.000209    1.000000

# %%
sns.heatmap(dataset.corr(numeric_only = True));

# %%
dataset.head(3)
# Out:
#   Employee_ID        Full_Name Department          Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen         IT  Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams  Marketing     SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez         HR         HR Manager 2023-03-20
#
#                            Location  Performance_Rating  Experience_Years  \
# 0                Isaacland, Denmark                   5                14
# 1           Anthonyside, Costa Rica                   2                 7
# 2  Port Christinaport, Saudi Arabia                   1                 2
#
#      Status Work_Mode  Salary_INR        Country
# 0  Resigned   On-site     1585363        Denmark
# 1    Active   On-site      847686     Costa Rica
# 2    Active   On-site     1430084   Saudi Arabia

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Employee_ID         object
#  1   Full_Name           object
#  2   Department          object
#  3   Job_Title           object
#  4   Hire_Date           datetime64[ns]
#  5   Location            object
#  6   Performance_Rating  int64
#  7   Experience_Years    int64
#  8   Status              object
#  9   Work_Mode           object
#  10  Salary_INR          int64
#  11  Country             object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 183.1+ MB

# %%
dataset.insert( 5 , 'Year', dataset['Hire_Date'].dt.year)

# %%
dataset
# Out:
#         Employee_ID         Full_Name  Department  \
# 0        EMP0000001     Joshua Nguyen          IT
# 1        EMP0000002    Julie Williams   Marketing
# 2        EMP0000003   Alyssa Martinez          HR
# 3        EMP0000004   Nicholas Valdez          IT
# 4        EMP0000005    Joel Hendricks  Operations
# ...             ...               ...         ...
# 1999995  EMP1999996      Cody Russell  Operations
# 1999996  EMP1999997      Tracey Smith          IT
# 1999997  EMP1999998         Tracy Lee       Sales
# 1999998  EMP1999999  Michael Roberson          IT
# 1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title  Hire_Date  Year  \
# 0                    Software Engineer 2011-08-10  2011
# 1                       SEO Specialist 2018-03-02  2018
# 2                           HR Manager 2023-03-20  2023
# 3                    Software Engineer 2023-10-12  2023
# 4                Logistics Coordinator 2024-12-09  2024
# ...

# %%
dataset.Year.unique()
# Out:
# array([2011, 2018, 2023, 2024, 2021, 2016, 2020, 2015, 2025, 2022, 2017,
#        2019, 2014, 2013, 2012, 2010], dtype=int32)

# %%
emp_year = dataset.groupby('Year')['Employee_ID'].count()

# %%
emp_year
# Out:
# Year
# 2010     15520
# 2011     40089
# 2012     39765
# 2013     39988
# 2014     40202
# 2015     85984
# 2016    160249
# 2017    160363
# 2018    159658
# 2019    160202
# 2020    175460
# 2021    199366
# 2022    201373
# 2023    198982
# 2024    200001
# 2025    122798
# Name: Employee_ID, dtype: int64

# %%
plt.figure(figsize = (9,5))
emp_year.plot(kind = 'bar' , x = emp_year.index, y = emp_year.values);
plt.grid(color = 'w')
plt.ylabel('Count');

# %%
dataset.head(5)
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#    Year                                 Location  Performance_Rating  \
# 0  2011                       Isaacland, Denmark                   5
# 1  2018                  Anthonyside, Costa Rica                   2
# 2  2023         Port Christinaport, Saudi Arabia                   1
# 3  2023  Port Shelbychester, Antigua and Barbuda                   1
# 4  2024     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR                 Country
# ...

# %%
re_os = dataset.groupby('Work_Mode')['Salary_INR'].mean()

# %%
re_os
# Out:
# Work_Mode
# On-site    896835.945792
# Remote     896965.326373
# Name: Salary_INR, dtype: float64

# %%
re_os.plot(kind = 'pie', shadow = True, autopct = '%1.1f%%');

# %%
dataset.head(2)
# Out:
#   Employee_ID       Full_Name Department          Job_Title  Hire_Date  Year  \
# 0  EMP0000001   Joshua Nguyen         IT  Software Engineer 2011-08-10  2011
# 1  EMP0000002  Julie Williams  Marketing     SEO Specialist 2018-03-02  2018
#
#                   Location  Performance_Rating  Experience_Years    Status  \
# 0       Isaacland, Denmark                   5                14  Resigned
# 1  Anthonyside, Costa Rica                   2                 7    Active
#
#   Work_Mode  Salary_INR      Country
# 0   On-site     1585363      Denmark
# 1   On-site      847686   Costa Rica

# %%
dataset.Department.unique()
# Out:
# array(['IT', 'Marketing', 'HR', 'Operations', 'Finance', 'Sales', 'R&D'],
#       dtype=object)

# %%
dataset[dataset.Department == 'IT'].sort_values(by = ['Salary_INR'] , ascending = False).head(10)
# Out:
#         Employee_ID           Full_Name Department   Job_Title  Hire_Date  \
# 1697605  EMP1697606       Kathryn Owens         IT  IT Manager 2018-02-22
# 1284141  EMP1284142       Robert Bowman         IT  IT Manager 2010-10-14
# 1912378  EMP1912379   Christina Delgado         IT  IT Manager 2018-06-24
# 1904593  EMP1904594        Donald Cohen         IT  IT Manager 2017-11-21
# 645146   EMP0645147   Brandon Rodriguez         IT  IT Manager 2016-09-11
# 766571   EMP0766572  Dr. David Mitchell         IT  IT Manager 2019-10-07
# 1257897  EMP1257898   Cassandra Morales         IT  IT Manager 2023-08-09
# 1734354  EMP1734355        Debra Rivera         IT  IT Manager 2022-06-13
# 369339   EMP0369340        Douglas Mann         IT  IT Manager 2021-12-22
# 1645827  EMP1645828   Jennifer Reynolds         IT  IT Manager 2021-02-05
#
#          Year                       Location  Performance_Rating  \
# 1697605  2018        Adamsborough, Greenland                   5
# ...

# %%
dataset[dataset.Department == 'Marketing'].sort_values(by = ['Salary_INR'] , ascending = False).head(10)
# Out:
#         Employee_ID       Full_Name Department            Job_Title  \
# 1268998  EMP1268999     Shannon Fox  Marketing  Marketing Executive
# 1015129  EMP1015130     Laura Allen  Marketing   Content Strategist
# 1214216  EMP1214217  Rebecca Davies  Marketing   Content Strategist
# 373011   EMP0373012     Dylan Davis  Marketing  Marketing Executive
# 158254   EMP0158255      Jamie Carr  Marketing  Marketing Executive
# 1848468  EMP1848469     Lisa Warren  Marketing  Marketing Executive
# 814806   EMP0814807    Daniel Cline  Marketing  Marketing Executive
# 1117910  EMP1117911     Tyler Fritz  Marketing   Content Strategist
# 1062763  EMP1062764     John Howard  Marketing  Marketing Executive
# 1468982  EMP1468983  Russell Parker  Marketing  Marketing Executive
#
#          Hire_Date  Year                                           Location  \
# 1268998 2017-10-30  2017  Lake Abigailhaven, South Georgia and the South...
# ...

# %%
dataset[dataset.Department == 'HR'].sort_values(by = ['Salary_INR'] , ascending = False).head(10)
# Out:
#         Employee_ID         Full_Name Department   Job_Title  Hire_Date  Year  \
# 223845   EMP0223846       Ethan Jones         HR  HR Manager 2021-03-09  2021
# 1068270  EMP1068271       Austin Hall         HR  HR Manager 2017-10-04  2017
# 1541972  EMP1541973     Daniel Wilson         HR  HR Manager 2025-04-18  2025
# 1861401  EMP1861402    Amanda Everett         HR  HR Manager 2010-09-29  2010
# 553718   EMP0553719   Michelle Snyder         HR  HR Manager 2018-04-06  2018
# 674999   EMP0675000   Andre Velasquez         HR  HR Manager 2021-08-03  2021
# 230232   EMP0230233      Carrie Davis         HR  HR Manager 2025-05-30  2025
# 1489953  EMP1489954   Gregory Pearson         HR  HR Manager 2022-03-06  2022
# 1863268  EMP1863269  Dr. Shawn Gibson         HR  HR Manager 2022-05-13  2022
# 1708267  EMP1708268        Anna Munoz         HR  HR Manager 2019-08-06  2019
#
#                                         Location  Performance_Rating  \
# ...

# %%
dataset[dataset.Department == 'Operations'].sort_values(by = ['Salary_INR'] , ascending = False).head(10)
# Out:
#         Employee_ID         Full_Name  Department             Job_Title  \
# 61771    EMP0061772  Rachel Rodriguez  Operations  Operations Executive
# 1145588  EMP1145589    Daniel Ramirez  Operations  Operations Executive
# 1219675  EMP1219676     Deborah Brown  Operations  Operations Executive
# 1462996  EMP1462997      John Stevens  Operations  Operations Executive
# 602560   EMP0602561     Cynthia Price  Operations  Supply Chain Manager
# 578541   EMP0578542     Joshua Flores  Operations  Operations Executive
# 1639976  EMP1639977    Stacie Johnson  Operations  Operations Executive
# 1511593  EMP1511594       Shannon Lee  Operations  Operations Executive
# 1729961  EMP1729962   Henry Hernandez  Operations  Operations Executive
# 1178609  EMP1178610       Mark Wilson  Operations  Operations Executive
#
#          Hire_Date  Year                                    Location  \
# 61771   2020-02-26  2020         Lake Anthonyborough, American Samoa
# ...

# %%
dataset[dataset.Department == 'Finance'].sort_values(by = ['Salary_INR'] , ascending = False).head(10)
# Out:
#         Employee_ID           Full_Name Department        Job_Title  \
# 888712   EMP0888713   Christopher Sloan    Finance  Finance Manager
# 695808   EMP0695809        Todd Rodgers    Finance  Finance Manager
# 459273   EMP0459274        Angela Payne    Finance  Finance Manager
# 750893   EMP0750894           Nina Lara    Finance  Finance Manager
# 780290   EMP0780291   Brittany Thompson    Finance  Finance Manager
# 1316795  EMP1316796        Larry Wilson    Finance  Finance Manager
# 737507   EMP0737508    Alexis Schroeder    Finance  Finance Manager
# 781352   EMP0781353         Sarah Jones    Finance  Finance Manager
# 803785   EMP0803786       Jose Anderson    Finance  Finance Manager
# 905337   EMP0905338  Jennifer Dominguez    Finance  Finance Manager
#
#          Hire_Date  Year                           Location  \
# 888712  2011-07-19  2011              East Ashley, Portugal
# 695808  2019-12-27  2019                North Taylor, Ghana
# ...

# %%
dataset[dataset.Department == 'Sales'].sort_values(by = ['Salary_INR'] , ascending = False).head(10)
# Out:
#         Employee_ID           Full_Name Department  \
# 1729875  EMP1729876         Hector Love      Sales
# 3493     EMP0003494          Tracy Hill      Sales
# 161163   EMP0161164         Mark Mccann      Sales
# 50430    EMP0050431      Christine Wood      Sales
# 339734   EMP0339735        Sarah Watson      Sales
# 86194    EMP0086195    Gabrielle Phelps      Sales
# 1116580  EMP1116581     Kimberly Mullen      Sales
# 1760918  EMP1760919  Christopher Farmer      Sales
# 1878661  EMP1878662    Margaret Gardner      Sales
# 1333220  EMP1333221      Benjamin Jones      Sales
#
#                             Job_Title  Hire_Date  Year  \
# 1729875  Business Development Manager 2020-01-02  2020
# 3493     Business Development Manager 2017-07-23  2017
# 161163   Business Development Manager 2025-06-09  2025
# 50430    Business Development Manager 2021-12-05  2021
# 339734   Business Development Manager 2021-04-05  2021
# 86194    Business Development Manager 2015-11-23  2015
# ...

# %%
dataset[dataset.Department == 'R&D'].sort_values(by = ['Salary_INR'] , ascending = False).head(10)
# Out:
#         Employee_ID        Full_Name Department           Job_Title  \
# 1601509  EMP1601510   Amanda Osborne        R&D  Research Scientist
# 1870413  EMP1870414    William Moore        R&D   Product Developer
# 1992769  EMP1992770   Whitney Guzman        R&D      Lab Technician
# 1143137  EMP1143138  Jeremy Buchanan        R&D      Lab Technician
# 1608754  EMP1608755    Rachel Pierce        R&D  Research Scientist
# 1452254  EMP1452255        Todd Rowe        R&D   Product Developer
# 1882072  EMP1882073     John Shepard        R&D   Product Developer
# 943039   EMP0943040     David Obrien        R&D  Research Scientist
# 137313   EMP0137314  Thomas Bautista        R&D  Research Scientist
# 196679   EMP0196680      Karen Lewis        R&D  Research Scientist
#
#          Hire_Date  Year                                    Location  \
# 1601509 2024-03-26  2024                        Lake Melinda, Panama
# 1870413 2020-12-30  2020                          Oscarville, Greece
# ...

# %%
# To watch combine data togather
dataset.head(3)
# Out:
#   Employee_ID        Full_Name Department          Job_Title  Hire_Date  Year  \
# 0  EMP0000001    Joshua Nguyen         IT  Software Engineer 2011-08-10  2011
# 1  EMP0000002   Julie Williams  Marketing     SEO Specialist 2018-03-02  2018
# 2  EMP0000003  Alyssa Martinez         HR         HR Manager 2023-03-20  2023
#
#                            Location  Performance_Rating  Experience_Years  \
# 0                Isaacland, Denmark                   5                14
# 1           Anthonyside, Costa Rica                   2                 7
# 2  Port Christinaport, Saudi Arabia                   1                 2
#
#      Status Work_Mode  Salary_INR        Country
# 0  Resigned   On-site     1585363        Denmark
# 1    Active   On-site      847686     Costa Rica
# 2    Active   On-site     1430084   Saudi Arabia

# %%
dataset.groupby('Department').apply(lambda x:x.nlargest(10, 'Salary_INR'), include_groups = False)
# Out:
#                    Employee_ID           Full_Name  \
# Department
# Finance    888712   EMP0888713   Christopher Sloan
#            695808   EMP0695809        Todd Rodgers
#            459273   EMP0459274        Angela Payne
#            750893   EMP0750894           Nina Lara
#            780290   EMP0780291   Brittany Thompson
# ...                        ...                 ...
# Sales      86194    EMP0086195    Gabrielle Phelps
#            1116580  EMP1116581     Kimberly Mullen
#            1760918  EMP1760919  Christopher Farmer
#            1878661  EMP1878662    Margaret Gardner
#            1333220  EMP1333221      Benjamin Jones
#
#                                        Job_Title  Hire_Date  Year  \
# Department
# Finance    888712                Finance Manager 2011-07-19  2011
#            695808                Finance Manager 2019-12-27  2019
#            459273                Finance Manager 2021-08-12  2021
# ...

# %%
dataset.head(5)
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#    Year                                 Location  Performance_Rating  \
# 0  2011                       Isaacland, Denmark                   5
# 1  2018                  Anthonyside, Costa Rica                   2
# 2  2023         Port Christinaport, Saudi Arabia                   1
# 3  2023  Port Shelbychester, Antigua and Barbuda                   1
# 4  2024     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode  Salary_INR                 Country
# ...

# %%
resigned_rate = dataset.groupby('Department')['Status'].agg(total_emp = 'count' , resigned = lambda x: (x == 'Resigned').sum())

# %%
resigned_rate
# Out:
#             total_emp  resigned
# Department
# Finance        199873     40238
# HR             159119     31736
# IT             601042    119852
# Marketing      240081     47793
# Operations     300095     59397
# R&D             99759     19919
# Sales          400031     79725

# %%
type(resigned_rate)
# Out:
# pandas.core.frame.DataFrame

# %%
resigned_rate['Attrition_rate'] = (resigned_rate['resigned'] / resigned_rate['total_emp'])*100

# %%
resigned_rate
# Out:
#             total_emp  resigned  Atttrition_rate  Attrition_rate
# Department
# Finance        199873     40238        20.131784       20.131784
# HR             159119     31736        19.944821       19.944821
# IT             601042    119852        19.940703       19.940703
# Marketing      240081     47793        19.907031       19.907031
# Operations     300095     59397        19.792732       19.792732
# R&D             99759     19919        19.967121       19.967121
# Sales          400031     79725        19.929705       19.929705

# %%
resigned_rate.drop(['Atttrition_rate'], axis = 1, inplace = True)

# %%
resigned_rate.sort_values(by = ['Attrition_rate'] , ascending = False)
# Out:
#             total_emp  resigned  Attrition_rate
# Department
# Finance        199873     40238       20.131784
# R&D             99759     19919       19.967121
# HR             159119     31736       19.944821
# IT             601042    119852       19.940703
# Sales          400031     79725       19.929705
# Marketing      240081     47793       19.907031
# Operations     300095     59397       19.792732
